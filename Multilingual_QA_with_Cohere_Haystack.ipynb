# %% [markdown]
# <a href="https://colab.research.google.com/github/bilgeyucel/multilingual-qa/blob/main/Multilingual_QA_with_Cohere_Haystack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Should I stay at this hotel?
#
# Multilingual Generative QA Using Cohere and Haystack

# %%
# !pip install farm-haystack[inference]
# Out:
# Collecting farm-haystack[inference]
#   Downloading farm_haystack-1.22.0-py3-none-any.whl (855 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.0/856.0 kB 13.0 MB/s eta 0:00:00
# Collecting boilerpy3 (from farm-haystack[inference])
#   Downloading boilerpy3-1.0.7-py3-none-any.whl (22 kB)
# Collecting events (from farm-haystack[inference])
#   Downloading Events-0.5-py3-none-any.whl (6.8 kB)
# Collecting httpx (from farm-haystack[inference])
#   Downloading httpx-0.25.1-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from farm-haystack[inference]) (4.19.1)
# Collecting lazy-imports==0.3.1 (from farm-haystack[inference])
#   Downloading lazy_imports-0.3.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from farm-haystack[inference]) (10.1.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from farm-haystack[inference]) (3.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from farm-haystack[inference]) (1.5.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from farm-haystack[inference]) (9.4.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from farm-haystack[inference]) (3.11.0)
# Collecting posthog (from farm-haystack[inference])
#   Downloading posthog-3.0.2-py2.py3-none-any.whl (37 kB)
# Collecting prompthub-py==4.0.0 (from farm-haystack[inference])
#   Downloading prompthub_py-4.0.0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: pydantic<2 in /usr/local/lib/python3.10/dist-packages (from farm-haystack[inference]) (1.10.13)
# Collecting quantulum3 (from farm-haystack[inference])
#   Downloading quantulum3-0.9.0-py3-none-any.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 103.1 MB/s eta 0:00:00
# Collecting rank-bm25 (from farm-haystack[inference])
#   Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from farm-haystack[inference]) (2.31.0)
# Collecting requests-cache<1.0.0 (from farm-haystack[inference])
#   Downloading requests_cache-0.9.8-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.7/48.7 kB 7.1 MB/s eta 0:00:00
# Collecting scikit-learn>=1.3.0 (from farm-haystack[inference])
#   Downloading scikit_learn-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 87.4 MB/s eta 0:00:00
# Collecting sseclient-py (from farm-haystack[inference])
#   Downloading sseclient_py-1.8.0-py2.py3-none-any.whl (8.8 kB)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.10/dist-packages (from farm-haystack[inference]) (8.2.3)
# Collecting tiktoken>=0.5.1 (from farm-haystack[inference])
#   Downloading tiktoken-0.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 97.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from farm-haystack[inference]) (4.66.1)
# Collecting transformers==4.34.1 (from farm-haystack[inference])
#   Downloading transformers-4.34.1-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 117.3 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.5.0 (from farm-haystack[inference])
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 38.9 MB/s eta 0:00:00
# Collecting sentence-transformers>=2.2.0 (from farm-haystack[inference])
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 13.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyyaml<7.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from prompthub-py==4.0.0->farm-haystack[inference]) (6.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.1->farm-haystack[inference]) (3.12.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.1->farm-haystack[inference]) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.1->farm-haystack[inference]) (23.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.1->farm-haystack[inference]) (2023.6.3)
# Collecting tokenizers<0.15,>=0.14 (from transformers==4.34.1->farm-haystack[inference])
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 61.9 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers==4.34.1->farm-haystack[inference])
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 96.7 MB/s eta 0:00:00
# Requirement already satisfied: torch!=1.12.0,>=1.10 in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.1->farm-haystack[inference]) (2.1.0+cu118)
# Collecting accelerate>=0.20.3 (from transformers==4.34.1->farm-haystack[inference])
#   Downloading accelerate-0.24.1-py3-none-any.whl (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 35.3 MB/s eta 0:00:00
# Collecting sentencepiece!=0.1.92,>=0.1.91 (from transformers==4.34.1->farm-haystack[inference])
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 36.5 MB/s eta 0:00:00
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers==4.34.1->farm-haystack[inference]) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.5.0->farm-haystack[inference]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.5.0->farm-haystack[inference]) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->farm-haystack[inference]) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->farm-haystack[inference]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->farm-haystack[inference]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->farm-haystack[inference]) (2023.7.22)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache<1.0.0->farm-haystack[inference]) (1.4.4)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache<1.0.0->farm-haystack[inference]) (23.1.0)
# Collecting cattrs>=22.2 (from requests-cache<1.0.0->farm-haystack[inference])
#   Downloading cattrs-23.1.2-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 7.1 MB/s eta 0:00:00
# Collecting url-normalize>=1.4 (from requests-cache<1.0.0->farm-haystack[inference])
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.0->farm-haystack[inference]) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.0->farm-haystack[inference]) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.0->farm-haystack[inference]) (3.2.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.0->farm-haystack[inference]) (0.16.0+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.0->farm-haystack[inference]) (3.8.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->farm-haystack[inference]) (3.7.1)
# Collecting httpcore (from httpx->farm-haystack[inference])
#   Downloading httpcore-1.0.1-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->farm-haystack[inference]) (1.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->farm-haystack[inference]) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->farm-haystack[inference]) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->farm-haystack[inference]) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->farm-haystack[inference]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->farm-haystack[inference]) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog->farm-haystack[inference]) (1.16.0)
# Collecting monotonic>=1.5 (from posthog->farm-haystack[inference])
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0 (from posthog->farm-haystack[inference])
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: inflect in /usr/local/lib/python3.10/dist-packages (from quantulum3->farm-haystack[inference]) (7.0.0)
# Collecting num2words (from quantulum3->farm-haystack[inference])
#   Downloading num2words-0.5.13-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.3/143.3 kB 20.8 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.3->transformers==4.34.1->farm-haystack[inference]) (5.9.5)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache<1.0.0->farm-haystack[inference]) (1.1.3)
# Collecting huggingface-hub>=0.5.0 (from farm-haystack[inference])
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 31.4 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers==4.34.1->farm-haystack[inference]) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers==4.34.1->farm-haystack[inference]) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers==4.34.1->farm-haystack[inference]) (2.1.0)
# Collecting h11<0.15,>=0.13 (from httpcore->httpx->farm-haystack[inference])
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=2.2.0->farm-haystack[inference]) (8.1.7)
# Collecting docopt>=0.6.2 (from num2words->quantulum3->farm-haystack[inference])
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch!=1.12.0,>=1.10->transformers==4.34.1->farm-haystack[inference]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch!=1.12.0,>=1.10->transformers==4.34.1->farm-haystack[inference]) (1.3.0)
# Building wheels for collected packages: sentence-transformers, docopt
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=665da2b821439b8805e364ca8a9ea65decd381f3a97e2c916efc7ab28f9f9fd8
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=4aa534372086a12abf889304ebd001c51563814f482c84616e9a7b86fa8c42aa
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built sentence-transformers docopt
# Installing collected packages: sseclient-py, sentencepiece, monotonic, events, docopt, url-normalize, safetensors, rank-bm25, num2words, lazy-imports, h11, cattrs, boilerpy3, backoff, tiktoken, scikit-learn, requests-cache, prompthub-py, posthog, huggingface-hub, httpcore, tokenizers, quantulum3, httpx, accelerate, transformers, sentence-transformers, farm-haystack
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# Successfully installed accelerate-0.24.1 backoff-2.2.1 boilerpy3-1.0.7 cattrs-23.1.2 docopt-0.6.2 events-0.5 farm-haystack-1.22.0 h11-0.14.0 httpcore-1.0.1 httpx-0.25.1 huggingface-hub-0.17.3 lazy-imports-0.3.1 monotonic-1.6 num2words-0.5.13 posthog-3.0.2 prompthub-py-4.0.0 quantulum3-0.9.0 rank-bm25-0.2.2 requests-cache-0.9.8 safetensors-0.4.0 scikit-learn-1.3.2 sentence-transformers-2.2.2 sentencepiece-0.1.99 sseclient-py-1.8.0 tiktoken-0.5.1 tokenizers-0.14.1 transformers-4.34.1 url-normalize-1.4.3

# %%
from getpass import getpass

COHERE_API_KEY = getpass("Enter Cohere API key:")
# Out:
# Enter Cohere API key:··········

# %%
from haystack.nodes import EmbeddingRetriever, PreProcessor
from haystack.document_stores import InMemoryDocumentStore
from haystack.pipelines import Pipeline
from haystack.schema import Document


document_store = InMemoryDocumentStore(embedding_dim=768, similarity= "dot_product")
retriever = EmbeddingRetriever(
    embedding_model="embed-multilingual-v2.0",
    document_store=document_store,
    api_key=COHERE_API_KEY
)
preprocessor = PreProcessor(
    clean_empty_lines=True,
    clean_whitespace=False,
    clean_header_footer=True,
    split_by="word",
    split_length=200,
    split_respect_sentence_boundary=True,
)

documents = [Document("O ar condicionado de um dos quartos deu problema, mas levaram um ventilador para ser utilizado. Também por ser em uma área bem movimentada, o barulho da rua pode ser ouvido. Porém, eles deixam protetores auriculares para o uso. Também senti falta de um espelho de corpo inteiro no apartamento. Só havia o do banheiro que mostra apenas a parte superior do corpo."),
             Document("Durchgängig Lärm, weil direkt an der Partymeile; schmutziges Geschirr; unvollständige Küchenausstattung; Abzugshaube über Herd ging für zwei Stunden automatisch an und lies sich nicht abstellen; Reaktionen auf Anfragen entweder gar nicht oder unfreundlich"),
             Document("Das Personal ist sehr zuvorkommend! Über WhatsApp war man im guten Kontakt und konnte alles erfragen. Auch das Angebot des Shuttleservices war super und würde ich empfehlen - sehr unkompliziert! Unser Flug hatte Verspätung und der Shuttle hat auf uns gewartet. Die Lage zur Innenstadt ist sehr gut,jedoch ist die Fensterfront direkt zur Club-Straße deshalb war es nachts bis drei/vier Uhr immer recht laut. Die Kaffeemaschine oder auch die Couch hätten sauberer sein können. Ansonsten war das Appartement aber völlig ok."),
             Document("Super appartement. Juste au dessus de plusieurs bars qui ferment très tard. A savoir à l'avance. (Bouchons d'oreilles fournis !)"),
             Document("Zapach moczu przy wejściu do budynku, może warto zainstalować tam mocne światło na czujnik ruchu, dla gości to korzystne a dla kogoś kto chciałby zrobić tam coś innego niekorzystne :-). Świetne lokalizacje w centrum niestety są na to narażane."),
             Document("El apartamento estaba genial y muy céntrico, todo a mano. Al lado de la librería Lello y De la Torre de los clérigos. Está situado en una zona de marcha, así que si vais en fin de semana , habrá ruido, aunque a nosotros no nos molestaba para dormir"),
             Document("The keypad with a code is convenient and the location is convenient. Basically everything else, very noisy, wi-fi didn't work, check-in person didn't explain anything about facilities, shower head was broken, there's no cleaning and everything else one may need is charged."),
             Document("It is very central and appartement has a nice appearance (even though a lot IKEA stuff), *W A R N I N G** the appartement presents itself as a elegant and as a place to relax, very wrong place to relax - you cannot sleep in this appartement, even the beds are vibrating from the bass of the clubs in the same building - you get ear plugs from the hotel -> now I understand why -> I missed a trip as it was so loud and I could not hear the alarm next day due to the ear plugs.- there is a green light indicating 'emergency exit' just above the bed, which shines very bright at night - during the arrival process, you felt the urge of the agent to leave as soon as possible. - try to go to 'RVA clerigos appartements' -> same price, super quiet, beautiful, city center and very nice staff (not an agency)- you are basically sleeping next to the fridge, which makes a lot of noise, when the compressor is running -> had to switch it off - but then had no cool food and drinks. - the bed was somehow broken down - the wooden part behind the bed was almost falling appart and some hooks were broken before- when the neighbour room is cooking you hear the fan very loud. I initially thought that I somehow activated the kitchen fan"),
             Document("Un peu salé surtout le sol. Manque de service et de souplesse"),
             Document("De comfort zo centraal voor die prijs."),
             Document("Die Lage war sehr Zentral und man konnte alles sehenswertes zu Fuß erreichen. Wer am Wochenende nachts schlafen möchte, sollte diese Unterkunft auf keinen Fall nehmen. Party direkt vor der Tür so das man denkt, man schläft mitten drin. Sehr Sehr laut also und das bis früh 5 Uhr. Ab 7 kommt dann die Straßenreinigung die keineswegs leiser ist."),
             Document("Ótima escolha! Apartamento confortável e limpo! O RoofTop é otimo para beber um vinho! O apartamento é localizado entre duas ruas de movimento noturno. Porem as janelas, blindam 90% do barulho. Não nos incomodou"),
             Document("Nous avons passé un séjour formidable. Merci aux personnes , le bonjours à Ricardo notre taxi man, très sympathique. Je pense refaire un séjour parmi vous, après le confinement, tout était parfait, surtout leur gentillesse, aucune chaude négative. Je n'ai rien à redire de négative, Ils étaient a notre écoute, un gentil message tout les matins, pour nous demander si nous avions besoins de renseignement et savoir si tout allait bien pendant notre séjour."),
             Document("Boa localização. Bom pequeno almoço. A tv não se encontrava funcional."),
             Document("Céntrico. Muy cómodo para moverse y ver Oporto. Edificio con terraza propia en la última planta. Todo reformado y nuevo. Te traen un estupendo desayuno todas las mañanas al apartamento. Solo que se puede escuchar algo de ruido de la calle a primeras horas de la noche. Es un zona de ocio nocturno. Pero respetan los horarios.")
]

indexing_pipeline = Pipeline()
indexing_pipeline.add_node(component=preprocessor, name="preprocessor", inputs=["File"])
indexing_pipeline.add_node(component=retriever, name="retriever", inputs=["preprocessor"])
indexing_pipeline.add_node(component=document_store, name="document_store", inputs=['retriever'])
indexing_pipeline.run(documents=documents)
# Out:
# Preprocessing: 100%|██████████| 15/15 [00:00<00:00, 2892.62docs/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  5.29it/s]
# {'documents': [<Document: {'content': 'O ar condicionado de um dos quartos deu problema, mas levaram um ventilador para ser utilizado. Também por ser em uma área bem movimentada, o barulho da rua pode ser ouvido. Porém, eles deixam protetores auriculares para o uso. Também senti falta de um espelho de corpo inteiro no apartamento. Só havia o do banheiro que mostra apenas a parte superior do corpo.', 'content_type': 'text', 'score': None, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': '<embedding of shape (768,)>', 'id': '5b171ca2c36c4a922f9cd3a1c460fad'}>,
#   <Document: {'content': 'Durchgängig Lärm, weil direkt an der Partymeile; schmutziges Geschirr; unvollständige Küchenausstattung; Abzugshaube über Herd ging für zwei Stunden automatisch an und lies sich nicht abstellen; Reaktionen auf Anfragen entweder gar nicht oder unfreundlich', 'content_type': 'text', 'score': None, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': '<embedding of shape (768,)>', 'id': '34a14bdffee8f4ac5e401e12ecb84e2b'}>,
#   <Document: {'content': 'Das Personal ist sehr zuvorkommend! Über WhatsApp war man im guten Kontakt und konnte alles erfragen. Auch das Angebot des Shuttleservices war super und würde ich empfehlen - sehr unkompliziert! Unser Flug hatte Verspätung und der Shuttle hat auf uns gewartet. Die Lage zur Innenstadt ist sehr gut,jedoch ist die Fensterfront direkt zur Club-Straße deshalb war es nachts bis drei/vier Uhr immer recht laut. Die Kaffeemaschine oder auch die Couch hätten sauberer sein können. Ansonsten war das Appartement aber völlig ok.', 'content_type': 'text', 'score': None, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': '<embedding of shape (768,)>', 'id': '239fa8f143ed26d7872f2c3d67396b5f'}>,
#   <Document: {'content': "Super appartement. Juste au dessus de plusieurs bars qui ferment très tard. A savoir à l'avance. (Bouchons d'oreilles fournis !)", 'content_type': 'text', 'score': None, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': '<embedding of shape (768,)>', 'id': '883cb92bef88095605d65f8d0f058de2'}>,
#   <Document: {'content': 'Zapach moczu przy wejściu do budynku, może warto zainstalować tam mocne światło na czujnik ruchu, dla gości to korzystne a dla kogoś kto chciałby zrobić tam coś innego niekorzystne :-). Świetne lokalizacje w centrum niestety są na to narażane.', 'content_type': 'text', 'score': None, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': '<embedding of shape (768,)>', 'id': '82e5d6de9f77ce3076c3906b2ed2baf2'}>,
#   <Document: {'content': 'El apartamento estaba genial y muy céntrico, todo a mano. Al lado de la librería Lello y De la Torre de los clérigos. Está situado en una zona de marcha, así que si vais en fin de semana , habrá ruido, aunque a nosotros no nos molestaba para dormir', 'content_type': 'text', 'score': None, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': '<embedding of shape (768,)>', 'id': 'fb027142af8ff79e551fef6b2d5225fa'}>,
#   <Document: {'content': "The keypad with a code is convenient and the location is convenient. Basically everything else, very noisy, wi-fi didn't work, check-in person didn't explain anything about facilities, shower head was broken, there's no cleaning and everything else one may need is charged.", 'content_type': 'text', 'score': None, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': '<embedding of shape (768,)>', 'id': 'a7745e19284ba8ec4f449b928f77a476'}>,
#   <Document: {'content': "It is very central and appartement has a nice appearance (even though a lot IKEA stuff), *W A R N I N G** the appartement presents itself as a elegant and as a place to relax, very wrong place to relax - you cannot sleep in this appartement, even the beds are vibrating from the bass of the clubs in the same building - you get ear plugs from the hotel -> now I understand why -> I missed a trip as it was so loud and I could not hear the alarm next day due to the ear plugs.- there is a green light indicating 'emergency exit' just above the bed, which shines very bright at night - during the arrival process, you felt the urge of the agent to leave as soon as possible. - try to go to 'RVA clerigos appartements' -> same price, super quiet, beautiful, city center and very nice staff (not an agency)- you are basically sleeping next to the fridge, which makes a lot of noise, when the compressor is running -> had to switch it off - but then had no cool food and drinks. ", 'content_type': 'text', 'score': None, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': '<embedding of shape (768,)>', 'id': '116c994d9b74fc37970a243aa896f58'}>,
#   <Document: {'content': '- the bed was somehow broken down - the wooden part behind the bed was almost falling appart and some hooks were broken before- when the neighbour room is cooking you hear the fan very loud. I initially thought that I somehow activated the kitchen fan', 'content_type': 'text', 'score': None, 'meta': {'_split_id': 1}, 'id_hash_keys': ['content'], 'embedding': '<embedding of shape (768,)>', 'id': 'c97add87d9e959b87d5b3b300e39f98'}>,
#   <Document: {'content': 'Un peu salé surtout le sol. Manque de service et de souplesse', 'content_type': 'text', 'score': None, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': '<embedding of shape (768,)>', 'id': '31e8854798e9800383be4ce5806cb6d3'}>,
#   <Document: {'content': 'De comfort zo centraal voor die prijs.', 'content_type': 'text', 'score': None, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': '<embedding of shape (768,)>', 'id': '29b9716e0b465d728bc64b7740312b48'}>,
#   <Document: {'content': 'Die Lage war sehr Zentral und man konnte alles sehenswertes zu Fuß erreichen. Wer am Wochenende nachts schlafen möchte, sollte diese Unterkunft auf keinen Fall nehmen. Party direkt vor der Tür so das man denkt, man schläft mitten drin. Sehr Sehr laut also und das bis früh 5 Uhr. Ab 7 kommt dann die Straßenreinigung die keineswegs leiser ist.', 'content_type': 'text', 'score': None, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': '<embedding of shape (768,)>', 'id': '3fbea54c97d2ca8ac0ae98abda19b5e8'}>,
#   <Document: {'content': 'Ótima escolha! Apartamento confortável e limpo! O RoofTop é otimo para beber um vinho! O apartamento é localizado entre duas ruas de movimento noturno. Porem as janelas, blindam 90% do barulho. Não nos incomodou', 'content_type': 'text', 'score': None, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': '<embedding of shape (768,)>', 'id': 'e24fa75d570f990efa91a3616b0604de'}>,
#   <Document: {'content': "Nous avons passé un séjour formidable. Merci aux personnes , le bonjours à Ricardo notre taxi man, très sympathique. Je pense refaire un séjour parmi vous, après le confinement, tout était parfait, surtout leur gentillesse, aucune chaude négative. Je n'ai rien à redire de négative, Ils étaient a notre écoute, un gentil message tout les matins, pour nous demander si nous avions besoins de renseignement et savoir si tout allait bien pendant notre séjour.", 'content_type': 'text', 'score': None, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': '<embedding of shape (768,)>', 'id': '3d984f53ca4954265fd3443459bc47c'}>,
#   <Document: {'content': 'Boa localização. Bom pequeno almoço. A tv não se encontrava funcional.', 'content_type': 'text', 'score': None, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': '<embedding of shape (768,)>', 'id': '733a5b6224505eb9359c62160c55a784'}>,
#   <Document: {'content': 'Céntrico. Muy cómodo para moverse y ver Oporto. Edificio con terraza propia en la última planta. Todo reformado y nuevo. Te traen un estupendo desayuno todas las mañanas al apartamento. Solo que se puede escuchar algo de ruido de la calle a primeras horas de la noche. Es un zona de ocio nocturno. Pero respetan los horarios.', 'content_type': 'text', 'score': None, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': '<embedding of shape (768,)>', 'id': 'e7fedbc9f5be5dbecbec03581e60dc1e'}>],
#  'root_node': 'File',
#  'params': {},
#  'node_id': 'document_store'}

# %%
from haystack.nodes import AnswerParser, PromptNode, PromptTemplate

prompt="""
You will be provided with reviews in multiple languages for an accommodation.
Create a concise and informative answer for a given question based solely on the given reviews.
\nReviews: {join(documents)}
\nQuestion: {query};
\nAnswer:
"""
template = PromptTemplate(
    prompt=prompt,
    output_parser=AnswerParser())

prompt_node = PromptNode(model_name_or_path="command", api_key=COHERE_API_KEY, default_prompt_template=template)

rag_pipeline = Pipeline()
rag_pipeline.add_node(component=retriever, name="Retriever", inputs=["Query"])
rag_pipeline.add_node(component=prompt_node, name="PromptNode", inputs=["Retriever"])
results = rag_pipeline.run("Is this place too noisy to sleep?", params={"Retriever": {"top_k": 3}})
print(results)
# Out:
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  5.68it/s]
# {'answers': [<Answer {'answer': " Based on the information provided in the reviews, it seems that the accommodation can be very noisy, especially at night. Multiple reviewers mentioned that the apartment is located in the same building as clubs, and the noise from these clubs, as well as from street cleaning in the early morning, can make it difficult to sleep. It is important to note that everyone's tolerance for noise can be different, so your experience may vary. \n\nIt is also worth considering that there are other options for accommodation in the", 'type': 'generative', 'score': None, 'context': None, 'offsets_in_document': None, 'offsets_in_context': None, 'document_ids': ['116c994d9b74fc37970a243aa896f58', 'a7745e19284ba8ec4f449b928f77a476', '3fbea54c97d2ca8ac0ae98abda19b5e8'], 'meta': {'prompt': "\nYou will be provided with reviews in multiple languages for an accommodation.\nCreate a concise and informative answer for a given question based solely on the given reviews.\n\nReviews: It is very central and appartement has a nice appearance (even though a lot IKEA stuff), *W A R N I N G** the appartement presents itself as a elegant and as a place to relax, very wrong place to relax - you cannot sleep in this appartement, even the beds are vibrating from the bass of the clubs in the same building - you get ear plugs from the hotel -> now I understand why -> I missed a trip as it was so loud and I could not hear the alarm next day due to the ear plugs.- there is a green light indicating 'emergency exit' just above the bed, which shines very bright at night - during the arrival process, you felt the urge of the agent to leave as soon as possible. - try to go to 'RVA clerigos appartements' -> same price, super quiet, beautiful, city center and very nice staff (not an agency)- you are basically sleeping next to the fridge, which makes a lot of noise, when the compressor is running -> had to switch it off - but then had no cool food and drinks.  The keypad with a code is convenient and the location is convenient. Basically everything else, very noisy, wi-fi didn't work, check-in person didn't explain anything about facilities, shower head was broken, there's no cleaning and everything else one may need is charged. Die Lage war sehr Zentral und man konnte alles sehenswertes zu Fuß erreichen. Wer am Wochenende nachts schlafen möchte, sollte diese Unterkunft auf keinen Fall nehmen. Party direkt vor der Tür so das man denkt, man schläft mitten drin. Sehr Sehr laut also und das bis früh 5 Uhr. Ab 7 kommt dann die Straßenreinigung die keineswegs leiser ist.\n\nQuestion: Is this place too noisy to sleep?;\n\nAnswer:\n"}}>], 'invocation_context': {'query': 'Is this place too noisy to sleep?', 'documents': [<Document: {'content': "It is very central and appartement has a nice appearance (even though a lot IKEA stuff), *W A R N I N G** the appartement presents itself as a elegant and as a place to relax, very wrong place to relax - you cannot sleep in this appartement, even the beds are vibrating from the bass of the clubs in the same building - you get ear plugs from the hotel -> now I understand why -> I missed a trip as it was so loud and I could not hear the alarm next day due to the ear plugs.- there is a green light indicating 'emergency exit' just above the bed, which shines very bright at night - during the arrival process, you felt the urge of the agent to leave as soon as possible. - try to go to 'RVA clerigos appartements' -> same price, super quiet, beautiful, city center and very nice staff (not an agency)- you are basically sleeping next to the fridge, which makes a lot of noise, when the compressor is running -> had to switch it off - but then had no cool food and drinks. ", 'content_type': 'text', 'score': 0.8120813881991849, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': None, 'id': '116c994d9b74fc37970a243aa896f58'}>, <Document: {'content': "The keypad with a code is convenient and the location is  ...

# %%
results = rag_pipeline.run("What are the problems about this place?", params={"Retriever": {"top_k": 10}})
print(results)
# Out:
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  3.88it/s]
# {'answers': [<Answer {'answer': ' Based on the information provided from the reviews, some of the issues guests have experienced include noisy accommodations, dysfunctional WiFi and appliances, unclean facilities, and poor customer service. Some reviewers also mentioned that the apartment complex is in a convenient location but is plagued by excessive noise from nearby clubs and loud neighbors. ', 'type': 'generative', 'score': None, 'context': None, 'offsets_in_document': None, 'offsets_in_context': None, 'document_ids': ['a7745e19284ba8ec4f449b928f77a476', '116c994d9b74fc37970a243aa896f58', 'c97add87d9e959b87d5b3b300e39f98', '5b171ca2c36c4a922f9cd3a1c460fad', '34a14bdffee8f4ac5e401e12ecb84e2b', '82e5d6de9f77ce3076c3906b2ed2baf2', '31e8854798e9800383be4ce5806cb6d3', '3fbea54c97d2ca8ac0ae98abda19b5e8', '733a5b6224505eb9359c62160c55a784', '29b9716e0b465d728bc64b7740312b48'], 'meta': {'prompt': "\nYou will be provided with reviews in multiple languages for an accommodation.\nCreate a concise and informative answer for a given question based solely on the given reviews.\n\nReviews: The keypad with a code is convenient and the location is convenient. Basically everything else, very noisy, wi-fi didn't work, check-in person didn't explain anything about facilities, shower head was broken, there's no cleaning and everything else one may need is charged. It is very central and appartement has a nice appearance (even though a lot IKEA stuff), *W A R N I N G** the appartement presents itself as a elegant and as a place to relax, very wrong place to relax - you cannot sleep in this appartement, even the beds are vibrating from the bass of the clubs in the same building - you get ear plugs from the hotel -> now I understand why -> I missed a trip as it was so loud and I could not hear the alarm next day due to the ear plugs.- there is a green light indicating 'emergency exit' just above the bed, which shines very bright at night - during the arrival process, you felt the urge of the agent to leave as soon as possible. - try to go to 'RVA clerigos appartements' -> same price, super quiet, beautiful, city center and very nice staff (not an agency)- you are basically sleeping next to the fridge, which makes a lot of noise, when the compressor is running -> had to switch it off - but then had no cool food and drinks.  - the bed was somehow broken down - the wooden part behind the bed was almost falling appart and some hooks were broken before- when the neighbour room is cooking you hear the fan very loud. I initially thought that I somehow activated the kitchen fan O ar condicionado de um dos quartos deu problema, mas levaram um ventilador para ser utilizado. Também por ser em uma área bem movimentada, o barulho da rua pode ser ouvido. Porém, eles deixam protetores auriculares para o uso. Também senti falta de um espelho de corpo inteiro no apartamento. Só havia o do banheiro que mostra apenas a parte superior do corpo. Durchgängig Lärm, weil direkt an der Partymeile; schmutziges Geschirr; unvollständige Küchenausstattung; Abzugshaube über Herd ging für zwei Stunden automatisch an und lies sich nicht abstellen; Reaktionen auf Anfragen entweder gar nicht oder unfreundlich Zapach moczu przy wejściu do budynku, może warto zainstalować tam mocne światło na czujnik ruchu, dla gości to korzystne a dla kogoś kto chciałby zrobić tam coś innego niekorzystne :-). Świetne lokalizacje w centrum niestety są na to narażane. Un peu salé surtout le sol. Manque de service et de souplesse Die Lage war sehr Zentral und man konnte alles sehenswertes zu Fuß erreichen. Wer am Wochenende nachts schlafen möchte, sollte diese Unterkunft auf keinen Fall nehmen. Party direkt vor der Tür so das man denkt, man schläft mitten drin. Sehr Sehr laut also und das bis früh 5 Uhr. Ab 7 kommt dann die Straßenreinigung die keineswegs leiser ist. Boa localização. Bom pequeno almoço. A tv não se encontrava funcional. De comfort zo centraal voor die prijs.\n\nQuestion: What are the ...

# %%
results = rag_pipeline.run("What is good about this place?", params={"Retriever": {"top_k": 10}})
print(results)
# Out:
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  7.64it/s]
# {'answers': [<Answer {'answer': ' The keypad with a code is convenient, the location is convenient, it is very central and the apartment has a nice appearance, and the breakfast they provide is amazing.', 'type': 'generative', 'score': None, 'context': None, 'offsets_in_document': None, 'offsets_in_context': None, 'document_ids': ['a7745e19284ba8ec4f449b928f77a476', '116c994d9b74fc37970a243aa896f58', '29b9716e0b465d728bc64b7740312b48', 'e7fedbc9f5be5dbecbec03581e60dc1e', '733a5b6224505eb9359c62160c55a784', '883cb92bef88095605d65f8d0f058de2', '82e5d6de9f77ce3076c3906b2ed2baf2', '31e8854798e9800383be4ce5806cb6d3', '3d984f53ca4954265fd3443459bc47c', '3fbea54c97d2ca8ac0ae98abda19b5e8'], 'meta': {'prompt': "\nYou will be provided with reviews in multiple languages for an accommodation.\nCreate a concise and informative answer for a given question based solely on the given reviews.\n\nReviews: The keypad with a code is convenient and the location is convenient. Basically everything else, very noisy, wi-fi didn't work, check-in person didn't explain anything about facilities, shower head was broken, there's no cleaning and everything else one may need is charged. It is very central and appartement has a nice appearance (even though a lot IKEA stuff), *W A R N I N G** the appartement presents itself as a elegant and as a place to relax, very wrong place to relax - you cannot sleep in this appartement, even the beds are vibrating from the bass of the clubs in the same building - you get ear plugs from the hotel -> now I understand why -> I missed a trip as it was so loud and I could not hear the alarm next day due to the ear plugs.- there is a green light indicating 'emergency exit' just above the bed, which shines very bright at night - during the arrival process, you felt the urge of the agent to leave as soon as possible. - try to go to 'RVA clerigos appartements' -> same price, super quiet, beautiful, city center and very nice staff (not an agency)- you are basically sleeping next to the fridge, which makes a lot of noise, when the compressor is running -> had to switch it off - but then had no cool food and drinks.  De comfort zo centraal voor die prijs. Céntrico. Muy cómodo para moverse y ver Oporto. Edificio con terraza propia en la última planta. Todo reformado y nuevo. Te traen un estupendo desayuno todas las mañanas al apartamento. Solo que se puede escuchar algo de ruido de la calle a primeras horas de la noche. Es un zona de ocio nocturno. Pero respetan los horarios. Boa localização. Bom pequeno almoço. A tv não se encontrava funcional. Super appartement. Juste au dessus de plusieurs bars qui ferment très tard. A savoir à l'avance. (Bouchons d'oreilles fournis !) Zapach moczu przy wejściu do budynku, może warto zainstalować tam mocne światło na czujnik ruchu, dla gości to korzystne a dla kogoś kto chciałby zrobić tam coś innego niekorzystne :-). Świetne lokalizacje w centrum niestety są na to narażane. Un peu salé surtout le sol. Manque de service et de souplesse Nous avons passé un séjour formidable. Merci aux personnes , le bonjours à Ricardo notre taxi man, très sympathique. Je pense refaire un séjour parmi vous, après le confinement, tout était parfait, surtout leur gentillesse, aucune chaude négative. Je n'ai rien à redire de négative, Ils étaient a notre écoute, un gentil message tout les matins, pour nous demander si nous avions besoins de renseignement et savoir si tout allait bien pendant notre séjour. Die Lage war sehr Zentral und man konnte alles sehenswertes zu Fuß erreichen. Wer am Wochenende nachts schlafen möchte, sollte diese Unterkunft auf keinen Fall nehmen. Party direkt vor der Tür so das man denkt, man schläft mitten drin. Sehr Sehr laut also und das bis früh 5 Uhr. Ab 7 kommt dann die Straßenreinigung die keineswegs leiser ist.\n\nQuestion: What is good about this place?;\n\nAnswer:\n"}}>], 'invocation_context': {'query': 'What is good about this place?', 'documents': [<Document: {'content': "The keypad ...

# %%
results = rag_pipeline.run("Should I stay at this hotel?", params={"Retriever": {"top_k": 10}})
print(results)
# Out:
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  8.47it/s]
# {'answers': [<Answer {'answer': ' The overall consensus of these reviews is that while the apartment is conveniently located, it is very loud, and guests are provided with earplugs. If quiet is an important feature for you in a hotel, this may not be the right fit. On the other hand, if you are looking for a centrally located place where you can stay up late, this may be a good option for you. A different accommodation with similar pricing and a strong staff is also available and may suit your needs. ', 'type': 'generative', 'score': None, 'context': None, 'offsets_in_document': None, 'offsets_in_context': None, 'document_ids': ['116c994d9b74fc37970a243aa896f58', '3fbea54c97d2ca8ac0ae98abda19b5e8', '239fa8f143ed26d7872f2c3d67396b5f', '3d984f53ca4954265fd3443459bc47c', 'a7745e19284ba8ec4f449b928f77a476', '883cb92bef88095605d65f8d0f058de2', 'e7fedbc9f5be5dbecbec03581e60dc1e', '82e5d6de9f77ce3076c3906b2ed2baf2', 'e24fa75d570f990efa91a3616b0604de', '5b171ca2c36c4a922f9cd3a1c460fad'], 'meta': {'prompt': "\nYou will be provided with reviews in multiple languages for an accommodation.\nCreate a concise and informative answer for a given question based solely on the given reviews.\n\nReviews: It is very central and appartement has a nice appearance (even though a lot IKEA stuff), *W A R N I N G** the appartement presents itself as a elegant and as a place to relax, very wrong place to relax - you cannot sleep in this appartement, even the beds are vibrating from the bass of the clubs in the same building - you get ear plugs from the hotel -> now I understand why -> I missed a trip as it was so loud and I could not hear the alarm next day due to the ear plugs.- there is a green light indicating 'emergency exit' just above the bed, which shines very bright at night - during the arrival process, you felt the urge of the agent to leave as soon as possible. - try to go to 'RVA clerigos appartements' -> same price, super quiet, beautiful, city center and very nice staff (not an agency)- you are basically sleeping next to the fridge, which makes a lot of noise, when the compressor is running -> had to switch it off - but then had no cool food and drinks.  Die Lage war sehr Zentral und man konnte alles sehenswertes zu Fuß erreichen. Wer am Wochenende nachts schlafen möchte, sollte diese Unterkunft auf keinen Fall nehmen. Party direkt vor der Tür so das man denkt, man schläft mitten drin. Sehr Sehr laut also und das bis früh 5 Uhr. Ab 7 kommt dann die Straßenreinigung die keineswegs leiser ist. Das Personal ist sehr zuvorkommend! Über WhatsApp war man im guten Kontakt und konnte alles erfragen. Auch das Angebot des Shuttleservices war super und würde ich empfehlen - sehr unkompliziert! Unser Flug hatte Verspätung und der Shuttle hat auf uns gewartet. Die Lage zur Innenstadt ist sehr gut,jedoch ist die Fensterfront direkt zur Club-Straße deshalb war es nachts bis drei/vier Uhr immer recht laut. Die Kaffeemaschine oder auch die Couch hätten sauberer sein können. Ansonsten war das Appartement aber völlig ok. Nous avons passé un séjour formidable. Merci aux personnes , le bonjours à Ricardo notre taxi man, très sympathique. Je pense refaire un séjour parmi vous, après le confinement, tout était parfait, surtout leur gentillesse, aucune chaude négative. Je n'ai rien à redire de négative, Ils étaient a notre écoute, un gentil message tout les matins, pour nous demander si nous avions besoins de renseignement et savoir si tout allait bien pendant notre séjour. The keypad with a code is convenient and the location is convenient. Basically everything else, very noisy, wi-fi didn't work, check-in person didn't explain anything about facilities, shower head was broken, there's no cleaning and everything else one may need is charged. Super appartement. Juste au dessus de plusieurs bars qui ferment très tard. A savoir à l'avance. (Bouchons d'oreilles fournis !) Céntrico. Muy cómodo para moverse y ver Oporto. Edificio con terraza propia en la última planta. ...

# %%
results = rag_pipeline.run("How is the wifi?", params={"Retriever": {"top_k": 3}})
print(results)
# Out:
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  7.11it/s]
# {'answers': [<Answer {'answer': ' The wifi is not great, it did not work well for many guests.', 'type': 'generative', 'score': None, 'context': None, 'offsets_in_document': None, 'offsets_in_context': None, 'document_ids': ['a7745e19284ba8ec4f449b928f77a476', '31e8854798e9800383be4ce5806cb6d3', '29b9716e0b465d728bc64b7740312b48'], 'meta': {'prompt': "\nYou will be provided with reviews in multiple languages for an accommodation.\nCreate a concise and informative answer for a given question based solely on the given reviews.\n\nReviews: The keypad with a code is convenient and the location is convenient. Basically everything else, very noisy, wi-fi didn't work, check-in person didn't explain anything about facilities, shower head was broken, there's no cleaning and everything else one may need is charged. Un peu salé surtout le sol. Manque de service et de souplesse De comfort zo centraal voor die prijs.\n\nQuestion: How is the wifi?;\n\nAnswer:\n"}}>], 'invocation_context': {'query': 'How is the wifi?', 'documents': [<Document: {'content': "The keypad with a code is convenient and the location is convenient. Basically everything else, very noisy, wi-fi didn't work, check-in person didn't explain anything about facilities, shower head was broken, there's no cleaning and everything else one may need is charged.", 'content_type': 'text', 'score': 0.8051968130898064, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': None, 'id': 'a7745e19284ba8ec4f449b928f77a476'}>, <Document: {'content': 'Un peu salé surtout le sol. Manque de service et de souplesse', 'content_type': 'text', 'score': 0.7966859808228265, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': None, 'id': '31e8854798e9800383be4ce5806cb6d3'}>, <Document: {'content': 'De comfort zo centraal voor die prijs.', 'content_type': 'text', 'score': 0.7963506784029132, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': None, 'id': '29b9716e0b465d728bc64b7740312b48'}>], 'answers': [<Answer {'answer': ' The wifi is not great, it did not work well for many guests.', 'type': 'generative', 'score': None, 'context': None, 'offsets_in_document': None, 'offsets_in_context': None, 'document_ids': ['a7745e19284ba8ec4f449b928f77a476', '31e8854798e9800383be4ce5806cb6d3', '29b9716e0b465d728bc64b7740312b48'], 'meta': {'prompt': "\nYou will be provided with reviews in multiple languages for an accommodation.\nCreate a concise and informative answer for a given question based solely on the given reviews.\n\nReviews: The keypad with a code is convenient and the location is convenient. Basically everything else, very noisy, wi-fi didn't work, check-in person didn't explain anything about facilities, shower head was broken, there's no cleaning and everything else one may need is charged. Un peu salé surtout le sol. Manque de service et de souplesse De comfort zo centraal voor die prijs.\n\nQuestion: How is the wifi?;\n\nAnswer:\n"}}>], 'prompts': ["\nYou will be provided with reviews in multiple languages for an accommodation.\nCreate a concise and informative answer for a given question based solely on the given reviews.\n\nReviews: The keypad with a code is convenient and the location is convenient. Basically everything else, very noisy, wi-fi didn't work, check-in person didn't explain anything about facilities, shower head was broken, there's no cleaning and everything else one may need is charged. Un peu salé surtout le sol. Manque de service et de souplesse De comfort zo centraal voor die prijs.\n\nQuestion: How is the wifi?;\n\nAnswer:\n"]}, 'documents': [<Document: {'content': "The keypad with a code is convenient and the location is convenient. Basically everything else, very noisy, wi-fi didn't work, check-in person didn't explain anything about facilities, shower head was broken, there's no cleaning and everything else one may need is charged.", 'content_type': 'text', 'score': 0.8051968130898064, 'meta': {'_split_id': 0}, 'id_hash_keys' ...

# %%
results = rag_pipeline.run("How can I use the coffee maker?", params={"Retriever": {"top_k": 3}})
print(results)
# Out:
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  3.26it/s]
# {'answers': [<Answer {'answer': ' There is no information provided in the reviews about how to use the coffee maker. \nIt is better to contact the accommodation provider for detailed instructions on how to use the coffee maker or any other equipment in the accommodation that you may need. ', 'type': 'generative', 'score': None, 'context': None, 'offsets_in_document': None, 'offsets_in_context': None, 'document_ids': ['a7745e19284ba8ec4f449b928f77a476', 'c97add87d9e959b87d5b3b300e39f98', '34a14bdffee8f4ac5e401e12ecb84e2b'], 'meta': {'prompt': "\nYou will be provided with reviews in multiple languages for an accommodation.\nCreate a concise and informative answer for a given question based solely on the given reviews.\n\nReviews: The keypad with a code is convenient and the location is convenient. Basically everything else, very noisy, wi-fi didn't work, check-in person didn't explain anything about facilities, shower head was broken, there's no cleaning and everything else one may need is charged. - the bed was somehow broken down - the wooden part behind the bed was almost falling appart and some hooks were broken before- when the neighbour room is cooking you hear the fan very loud. I initially thought that I somehow activated the kitchen fan Durchgängig Lärm, weil direkt an der Partymeile; schmutziges Geschirr; unvollständige Küchenausstattung; Abzugshaube über Herd ging für zwei Stunden automatisch an und lies sich nicht abstellen; Reaktionen auf Anfragen entweder gar nicht oder unfreundlich\n\nQuestion: How can I use the coffee maker?;\n\nAnswer:\n"}}>], 'invocation_context': {'query': 'How can I use the coffee maker?', 'documents': [<Document: {'content': "The keypad with a code is convenient and the location is convenient. Basically everything else, very noisy, wi-fi didn't work, check-in person didn't explain anything about facilities, shower head was broken, there's no cleaning and everything else one may need is charged.", 'content_type': 'text', 'score': 0.7976465696244552, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': None, 'id': 'a7745e19284ba8ec4f449b928f77a476'}>, <Document: {'content': '- the bed was somehow broken down - the wooden part behind the bed was almost falling appart and some hooks were broken before- when the neighbour room is cooking you hear the fan very loud. I initially thought that I somehow activated the kitchen fan', 'content_type': 'text', 'score': 0.7971425933446511, 'meta': {'_split_id': 1}, 'id_hash_keys': ['content'], 'embedding': None, 'id': 'c97add87d9e959b87d5b3b300e39f98'}>, <Document: {'content': 'Durchgängig Lärm, weil direkt an der Partymeile; schmutziges Geschirr; unvollständige Küchenausstattung; Abzugshaube über Herd ging für zwei Stunden automatisch an und lies sich nicht abstellen; Reaktionen auf Anfragen entweder gar nicht oder unfreundlich', 'content_type': 'text', 'score': 0.7927227583923275, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': None, 'id': '34a14bdffee8f4ac5e401e12ecb84e2b'}>], 'answers': [<Answer {'answer': ' There is no information provided in the reviews about how to use the coffee maker. \nIt is better to contact the accommodation provider for detailed instructions on how to use the coffee maker or any other equipment in the accommodation that you may need. ', 'type': 'generative', 'score': None, 'context': None, 'offsets_in_document': None, 'offsets_in_context': None, 'document_ids': ['a7745e19284ba8ec4f449b928f77a476', 'c97add87d9e959b87d5b3b300e39f98', '34a14bdffee8f4ac5e401e12ecb84e2b'], 'meta': {'prompt': "\nYou will be provided with reviews in multiple languages for an accommodation.\nCreate a concise and informative answer for a given question based solely on the given reviews.\n\nReviews: The keypad with a code is convenient and the location is convenient. Basically everything else, very noisy, wi-fi didn't work, check-in person didn't explain anything about facilities, shower head was broken, there's no clea ...

# %%
results = rag_pipeline.run("What are the attractions around this place?", params={"Retriever": {"top_k": 3}})
print(results)
# Out:
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  8.55it/s]
# {'answers': [<Answer {'answer': ' The accommodation is in a convenient location close to attractions such as the Porto City Hall and the Porto Cathedral. However, the reviews indicate that the accommodation itself has several issues, such as noise levels, broken amenities, and poor communication from staff, which may impact the overall experience. It is important to carefully consider these factors when deciding on a place to stay and to read reviews from multiple sources to get a full understanding of the property. ', 'type': 'generative', 'score': None, 'context': None, 'offsets_in_document': None, 'offsets_in_context': None, 'document_ids': ['a7745e19284ba8ec4f449b928f77a476', '3fbea54c97d2ca8ac0ae98abda19b5e8', '116c994d9b74fc37970a243aa896f58'], 'meta': {'prompt': "\nYou will be provided with reviews in multiple languages for an accommodation.\nCreate a concise and informative answer for a given question based solely on the given reviews.\n\nReviews: The keypad with a code is convenient and the location is convenient. Basically everything else, very noisy, wi-fi didn't work, check-in person didn't explain anything about facilities, shower head was broken, there's no cleaning and everything else one may need is charged. Die Lage war sehr Zentral und man konnte alles sehenswertes zu Fuß erreichen. Wer am Wochenende nachts schlafen möchte, sollte diese Unterkunft auf keinen Fall nehmen. Party direkt vor der Tür so das man denkt, man schläft mitten drin. Sehr Sehr laut also und das bis früh 5 Uhr. Ab 7 kommt dann die Straßenreinigung die keineswegs leiser ist. It is very central and appartement has a nice appearance (even though a lot IKEA stuff), *W A R N I N G** the appartement presents itself as a elegant and as a place to relax, very wrong place to relax - you cannot sleep in this appartement, even the beds are vibrating from the bass of the clubs in the same building - you get ear plugs from the hotel -> now I understand why -> I missed a trip as it was so loud and I could not hear the alarm next day due to the ear plugs.- there is a green light indicating 'emergency exit' just above the bed, which shines very bright at night - during the arrival process, you felt the urge of the agent to leave as soon as possible. - try to go to 'RVA clerigos appartements' -> same price, super quiet, beautiful, city center and very nice staff (not an agency)- you are basically sleeping next to the fridge, which makes a lot of noise, when the compressor is running -> had to switch it off - but then had no cool food and drinks. \n\nQuestion: What are the attractions around this place?;\n\nAnswer:\n"}}>], 'invocation_context': {'query': 'What are the attractions around this place?', 'documents': [<Document: {'content': "The keypad with a code is convenient and the location is convenient. Basically everything else, very noisy, wi-fi didn't work, check-in person didn't explain anything about facilities, shower head was broken, there's no cleaning and everything else one may need is charged.", 'content_type': 'text', 'score': 0.8028558200321344, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': None, 'id': 'a7745e19284ba8ec4f449b928f77a476'}>, <Document: {'content': 'Die Lage war sehr Zentral und man konnte alles sehenswertes zu Fuß erreichen. Wer am Wochenende nachts schlafen möchte, sollte diese Unterkunft auf keinen Fall nehmen. Party direkt vor der Tür so das man denkt, man schläft mitten drin. Sehr Sehr laut also und das bis früh 5 Uhr. Ab 7 kommt dann die Straßenreinigung die keineswegs leiser ist.', 'content_type': 'text', 'score': 0.8015004499326369, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': None, 'id': '3fbea54c97d2ca8ac0ae98abda19b5e8'}>, <Document: {'content': "It is very central and appartement has a nice appearance (even though a lot IKEA stuff), *W A R N I N G** the appartement presents itself as a elegant and as a place to relax, very wrong place to relax - you cannot sleep in this ap ...

# %%
results = rag_pipeline.run("Are there pubs near by?", params={"Retriever": {"top_k": 3}})
print(results)
# Out:
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  5.17it/s]
# {'answers': [<Answer {'answer': ' There are several pubs near by.', 'type': 'generative', 'score': None, 'context': None, 'offsets_in_document': None, 'offsets_in_context': None, 'document_ids': ['883cb92bef88095605d65f8d0f058de2', 'a7745e19284ba8ec4f449b928f77a476', '3fbea54c97d2ca8ac0ae98abda19b5e8'], 'meta': {'prompt': "\nYou will be provided with reviews in multiple languages for an accommodation.\nCreate a concise and informative answer for a given question based solely on the given reviews.\n\nReviews: Super appartement. Juste au dessus de plusieurs bars qui ferment très tard. A savoir à l'avance. (Bouchons d'oreilles fournis !) The keypad with a code is convenient and the location is convenient. Basically everything else, very noisy, wi-fi didn't work, check-in person didn't explain anything about facilities, shower head was broken, there's no cleaning and everything else one may need is charged. Die Lage war sehr Zentral und man konnte alles sehenswertes zu Fuß erreichen. Wer am Wochenende nachts schlafen möchte, sollte diese Unterkunft auf keinen Fall nehmen. Party direkt vor der Tür so das man denkt, man schläft mitten drin. Sehr Sehr laut also und das bis früh 5 Uhr. Ab 7 kommt dann die Straßenreinigung die keineswegs leiser ist.\n\nQuestion: Are there pubs near by?;\n\nAnswer:\n"}}>], 'invocation_context': {'query': 'Are there pubs near by?', 'documents': [<Document: {'content': "Super appartement. Juste au dessus de plusieurs bars qui ferment très tard. A savoir à l'avance. (Bouchons d'oreilles fournis !)", 'content_type': 'text', 'score': 0.8002500602614723, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': None, 'id': '883cb92bef88095605d65f8d0f058de2'}>, <Document: {'content': "The keypad with a code is convenient and the location is convenient. Basically everything else, very noisy, wi-fi didn't work, check-in person didn't explain anything about facilities, shower head was broken, there's no cleaning and everything else one may need is charged.", 'content_type': 'text', 'score': 0.8000822938159076, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': None, 'id': 'a7745e19284ba8ec4f449b928f77a476'}>, <Document: {'content': 'Die Lage war sehr Zentral und man konnte alles sehenswertes zu Fuß erreichen. Wer am Wochenende nachts schlafen möchte, sollte diese Unterkunft auf keinen Fall nehmen. Party direkt vor der Tür so das man denkt, man schläft mitten drin. Sehr Sehr laut also und das bis früh 5 Uhr. Ab 7 kommt dann die Straßenreinigung die keineswegs leiser ist.', 'content_type': 'text', 'score': 0.7991346911464476, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': None, 'id': '3fbea54c97d2ca8ac0ae98abda19b5e8'}>], 'answers': [<Answer {'answer': ' There are several pubs near by.', 'type': 'generative', 'score': None, 'context': None, 'offsets_in_document': None, 'offsets_in_context': None, 'document_ids': ['883cb92bef88095605d65f8d0f058de2', 'a7745e19284ba8ec4f449b928f77a476', '3fbea54c97d2ca8ac0ae98abda19b5e8'], 'meta': {'prompt': "\nYou will be provided with reviews in multiple languages for an accommodation.\nCreate a concise and informative answer for a given question based solely on the given reviews.\n\nReviews: Super appartement. Juste au dessus de plusieurs bars qui ferment très tard. A savoir à l'avance. (Bouchons d'oreilles fournis !) The keypad with a code is convenient and the location is convenient. Basically everything else, very noisy, wi-fi didn't work, check-in person didn't explain anything about facilities, shower head was broken, there's no cleaning and everything else one may need is charged. Die Lage war sehr Zentral und man konnte alles sehenswertes zu Fuß erreichen. Wer am Wochenende nachts schlafen möchte, sollte diese Unterkunft auf keinen Fall nehmen. Party direkt vor der Tür so das man denkt, man schläft mitten drin. Sehr Sehr laut also und das bis früh 5 Uhr. Ab 7 kommt dann die Straßenreinigung die keineswegs leiser ist.\n\nQuestio ...
